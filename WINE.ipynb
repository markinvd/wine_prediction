# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine
import PyCaret
full_data = load_wine()
data = full_data.data
tg = full_data.target
data= pd.DataFrame(data)

# %%
full_data.DESCR
# Out:
# '.. _wine_dataset:\n\nWine recognition dataset\n------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 178 (50 in each of three classes)\n    :Number of Attributes: 13 numeric, predictive attributes and the class\n    :Attribute Information:\n \t\t- Alcohol\n \t\t- Malic acid\n \t\t- Ash\n\t\t- Alcalinity of ash  \n \t\t- Magnesium\n\t\t- Total phenols\n \t\t- Flavanoids\n \t\t- Nonflavanoid phenols\n \t\t- Proanthocyanins\n\t\t- Color intensity\n \t\t- Hue\n \t\t- OD280/OD315 of diluted wines\n \t\t- Proline\n\n    - class:\n            - class_0\n            - class_1\n            - class_2\n\t\t\n    :Summary Statistics:\n    \n    ============================= ==== ===== ======= =====\n                                   Min   Max   Mean     SD\n    ============================= ==== ===== ======= =====\n    Alcohol:                      11.0  14.8    13.0   0.8\n    Malic Acid:                   0.74  5.80    2.34  1.12\n    Ash:                   
# ...

# %%
feature_names= ['alcohol',
  'malic_acid',
  'ash',
  'alcalinity_of_ash',
  'magnesium',
  'total_phenols',
  'flavanoids',
  'nonflavanoid_phenols',
  'proanthocyanins',
  'color_intensity',
  'hue',
  'od280/od315_of_diluted_wines',
  'proline']

# %%
tg = pd.DataFrame(tg)

# %%
data.columns = feature_names

# %%
data['resp'] = tg

# %%
#data = data.drop(['malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'nonflavanoid_phenols', 'proanthocyanins'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-c6f035d303c2> in <module>
# ----> 1 data = data.drop(['malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'nonflavanoid_phenols', 'proanthocyanins'], axis=1)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
import lux

# %%
data
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
data.intent = ['flavanoids', 'alcohol','resp']
data
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
import pandas as pd
import numpy as np


corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
corr.style.background_gradient(cmap='coolwarm',axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_e457f_row0_col0,#T_e457f_row1_col1,#T_e457f_row2_col2,#T_e457f_row3_col3,#T_e457f_row4_col4,#T_e457f_row5_col5,#T_e457f_row6_col6,#T_e457f_row7_col7,#T_e457f_row8_col8,#T_e457f_row9_col9,#T_e457f_row10_col10,#T_e457f_row11_col11,#T_e457f_row12_col12,#T_e457f_row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e457f_row0_col1,#T_e457f_row1_col0{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_e457f_row0_col2,#T_e457f_row2_col0{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_e457f_row0_col3,#T_e457f_row3_col0,#T_e457f_row7_col12,#T_e457f_row12_col7{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_e457f_row0_col4,#T_e457f_row4_col0,#T_e457f_row9_col13,#T_e457f_row13_col9{
#             background-color:  #f2cab5;
#             color:  #000000;
# ...

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(10, 8))
corr = data.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3c7e292c6cba> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 f, ax = plt.subplots(figsize=(10, 8))
#       4 corr = data.corr()
#       5 sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
#
# NameError: name 'plt' is not defined

# %%
from pycaret.classification import *

clf = setup(data = data, target = 'resp',train_size = 0.8)
# Out:
# <style  type="text/css" >
# </style><table id="T_34b8a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34b8a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_34b8a_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_34b8a_row0_col1" class="data row0 col1" >704</td>
#             </tr>
#             <tr>
#                         <th id="T_34b8a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_34b8a_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_34b8a_row1_col1" class="data row1 col1" >resp</td>
#             </tr>
#             <tr>
#                         <th id="T_34b8a_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best3 = compare_models(n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_fc1dc_ th {
#           text-align: left;
# ...

# %%
best3
# Out:
# [QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                store_covariance=False, tol=0.0001),
#  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                       criterion='gini', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, max_samples=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                       oob_score=False, random_state=704, verbose=0,
#                       warm_start=False),
#  RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                  max_iter=None, normalize=False, random_state=704, solver='auto',
#                  tol=0.001)]

# %%
#create model
# default number of folds =10
rf = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_0a755_row10_col0,#T_0a755_row10_col1,#T_0a755_row10_col2,#T_0a755_row10_col3,#T_0a755_row10_col4,#T_0a755_row10_col5,#T_0a755_row10_col6{
#             background:  yellow;
#         }</style><table id="T_0a755_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a755_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0a755_row0_col0" class="data row0 col0" >1.0000</td>
# ...

# %%
predict_model(rf)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b6ca_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b6ca_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9b6ca_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#                         <td id="T_9b6ca_row0_col1" class="data row0 col1" >0.9722</td>
#                         <td id="T_9b6ca_row0_col2" class="data row0 col2" >1.0000</td>
# ...

# %%
rf.feature_importances_
# Out:
# array([0.12487826, 0.02764036, 0.00959195, 0.0198308 , 0.02016984,
#        0.0416554 , 0.18031256, 0.01037653, 0.02871952, 0.17147287,
#        0.10042324, 0.09366869, 0.17125999])

# %%
data.head()
['malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'nomflavanoid_phenols', 'proanthocyanins']
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
et = create_model('et', fold=10)
# Out:
# <style  type="text/css" >
# #T_e1986_row10_col0,#T_e1986_row10_col1,#T_e1986_row10_col2,#T_e1986_row10_col3,#T_e1986_row10_col4,#T_e1986_row10_col5,#T_e1986_row10_col6{
#             background:  yellow;
#         }</style><table id="T_e1986_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1986_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e1986_row0_col0" class="data row0 col0" >1.0000</td>
# ...

# %%
plot_model(et,plot='confusion_matrix')

# %%
evaluate_model(et)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
et.feature_importances_
# Out:
# array([0.10919618, 0.03511616, 0.02422936, 0.03239138, 0.03253881,
#        0.06468051, 0.18238803, 0.02741969, 0.03449071, 0.09610441,
#        0.08663431, 0.11654438, 0.15826609])

# %%
feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
predict_model(et)
# Out:
# <style  type="text/css" >
# </style><table id="T_762eb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_762eb_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_762eb_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_762eb_row0_col1" class="data row0 col1" >0.9722</td>
#                         <td id="T_762eb_row0_col2" class="data row0 col2" >1.0000</td>
# ...

# %%
interpret_model(et, plot='correlation')

# %%
interpret_model(et)

# %%
interpret_model(et, plot='reason')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
interpret_model(et, plot='summary')

# %%
plot_model(et, plot='feature')

# %%
plot_model(et, plot='vc')

# %%
plot_model(et, plot='class_report')

# %%
plot_model(et, plot='boundary')

# %%
import lux

# %%
data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...
